# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Step 1: Import necessary libraries
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from qcObjectdetection import detect_objects
from RulerSizeDetection import detect_ruler_size
from DirtyMarkClassifier import classify_defects

# Step 2: Load the trained models
object_detection_model = load_model("path_to_object_detection_model.h5")
ruler_size_detection_model = load_model("path_to_ruler_size_detection_model.h5")
dirty_mark_classifier_model = load_model("path_to_dirty_mark_classifier_model.h5")

# Step 3: Define function for defect detection, classification, and size detection
def detect_defect(image):
    # Step 4: Detect objects in the image
    detected_objects = detect_objects(image)

    # Step 5: Initialize variables for defect type and size
    defect_type = None
    defect_size = None

    # Step 6: Check if any defects are detected
    defect_detected = False
    for obj in detected_objects:
        if obj['class'] != 'Dirty Mark':
            defect_detected = True
            break

    if defect_detected:
        # Step 7: For each detected defect object
        for obj in detected_objects:
            if obj['class'] != 'Dirty Mark':
                # Step 8: Classify defect type
                defect_type = classify_defects(obj['object'])

                # Step 9: Detect ruler size
                ruler_size = detect_ruler_size(obj['object'])

                # Step 10: Detect defect size
                defect_size = #pixel ratio calculation with ref ruler_size pixel and inch.

                # Step 11: Output defect details
                print("Defect Type:", defect_type)
                print("Defect Size:", defect_size)

    else:
        print("No defects found.")

# Step 12: Load the image
image_path = "path_to_image.jpg"
image = cv2.imread(image_path)

# Step 13: Detect defects, identify type and size, and display details
detect_defect(image)
